# %% [markdown]
# # Netflix Content Analysis
#
# This project explores a dataset of Netflix titles (Movies and TV Shows) sourced from Kaggle, containing ~8,800 entries with details like genre, country, release year, and date added.
#
# The goal is to answer a few questions about Netflix's content strategy:
# - How has the number of titles added changed over time?
# - What's the split between Movies and TV Shows?
# - Which countries produce the most content on the platform?
# - What are the most (and least) common genres?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe(include ='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['country'].unique()
# Out:
# <StringArray>
# [                                                        'United States',
#                                                           'South Africa',
#                                                                      nan,
#                                                                  'India',
#  'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#                                                         'United Kingdom',
#                                                'Germany, Czech Republic',
#                                                                 'Mexico',
#                                                                 'Turkey',
#                                                              'Australia',
#  ...
#                         'Germany, United States, United Kingdom, Canada',
#           'Canada, India, Thailand, United States, United Arab Emirates',
# ...

# %%
df['date_added']= df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['date_added'].dtype
# Out:
# dtype('<M8[us]')

# %%
df = df.fillna({
   'director' : 'unknown',
    'cast' : 'unknown',
    'country' : 'unknown'
})
df =df.dropna(subset=['duration','date_added','rating'])
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
#best approach for splitting here 
df_countries = df.copy()
#.str.split(',') turns "United States, India" into a list: ['United States', ' India']
df_countries['country'] = df_countries['country'].str.split(',')
#.explode('country') takes that list and turns it into multiple rows — one row per country, duplicating every other column's value across them.
df_countries = df_countries.explode('country')
# .str.strip() removes the leftover leading space that splitting on , creates (" India" → "India")
df_countries['country'] =df_countries['country'].str.strip()
df_countries
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_countries.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df_countries['country'].value_counts().head(1)
# Out:
# country
# United States    3681
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['date_added'] = df['date_added'].dt.year
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added'].value_counts().sort_index()
# Out:
# date_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     426
# 2017    1185
# 2018    1648
# 2019    2016
# 2020    1879
# 2021    1498
# Name: count, dtype: int64

# %%
df['date_added'].value_counts().sort_index()
# Out:
# date_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     426
# 2017    1185
# 2018    1648
# 2019    2016
# 2020    1879
# 2021    1498
# Name: count, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df_countries['country'].value_counts().sort_index()
# Out:
# country
#                   7
# Afghanistan       1
# Albania           1
# Algeria           3
# Angola            1
#                ...
# Venezuela         4
# Vietnam           7
# West Germany      5
# Zimbabwe          3
# unknown         829
# Name: count, Length: 124, dtype: int64

# %%
df['rating'].value_counts().sort_index()
# Out:
# rating
# G             41
# NC-17          3
# NR            79
# PG           287
# PG-13        490
# R            799
# TV-14       2157
# TV-G         220
# TV-MA       3205
# TV-PG        861
# TV-Y         306
# TV-Y7        333
# TV-Y7-FV       6
# UR             3
# Name: count, dtype: int64

# %%
df_lists = df.copy()
df_lists['listed_in'] = df_lists['listed_in'].str.split(',')
df_lists = df_lists.explode('listed_in')
df_lists['listed_in'] = df_lists['listed_in'].str.strip()
df_lists
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 1         s2  TV Show         Blood & Water          unknown
# 2         s3  TV Show             Ganglands  Julien Leclercq
# ...      ...      ...                   ...              ...
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_countries.groupby(by=['type','country']).size().sort_values(ascending = True)
# Out:
# type     country
# Movie    Slovakia             1
# TV Show  Cyprus               1
#          Cuba                 1
#          Croatia              1
# Movie    Jamaica              1
#                            ...
#          unknown            439
#          United Kingdom     534
# TV Show  United States      932
# Movie    India              962
#          United States     2749
# Length: 186, dtype: int64

# %%
df_lists['listed_in'].value_counts()
# Out:
# listed_in
# International Movies            2752
# Dramas                          2426
# Comedies                        1674
# International TV Shows          1349
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        762
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# Thrillers                        577
# TV Comedies                      573
# Crime TV Shows                   469
# Kids' TV                         448
# Docuseries                       394
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 252
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     174
# Spanish-Language TV Shows        173
# ...

# %%
year_counts = df['date_added'].value_counts().sort_index()

plt.figure(figsize=(10,6))
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('Netflix Titles Added Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Titles Added')
plt.show()

# %% [markdown]
# Titles added peaked in 2019, probably from Netflix's expansion phase before COVID slowed things down in the next couple years.

# %%
type_counts = df['type'].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=type_counts.index, y=type_counts.values)
plt.title('Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# The bar chart shows a big gap between Movies and TV Shows on Netflix, with Movies being much more common. This might be because movies are a smaller time commitment , easier to watch in one sitting compared to a full TV series.

# %%
top_countries = df_countries['country'].value_counts().head(10)
plt.figure(figsize=(15,6))
sns.barplot(x=top_countries.values,y=top_countries.index)
plt.title('Top 10 countries')
plt.xlabel('Titles added')
plt.ylabel('country')
plt.show()

# %% [markdown]
# This bar chart shows the top 10 countries by number of titles added, with the United States at the top. This makes sense since the US produces a lot of English-language content, which has a wide global audience.

# %%
type_genres = df_lists['listed_in'].value_counts().head(10)
plt.figure(figsize = (10,6))
sns.barplot(x = type_genres.values, y = type_genres.index)
plt.title('top 10 genres')
plt.xlabel('Titles added')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# This bar chart shows the top 10 genres by number of titles, with International Movies at the top. This makes sense since it's a broad category that helps Netflix reach a wider global audience.
